# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import math
from pyclustering.nnet.som import type_conn
from matrixprofile import matrixProfile, motifs
# local code
# import sys
# sys.path.insert(0, os.path.abspath('../src'))
import dtwsom

# %% [markdown]
# ## 🎲 *Loading data*

# %%
D3011_data = np.load('dataset_TipAu_Au.npz')

# %%
D3011_data.keys()
# Out:
# KeysView(NpzFile 'dataset_TipAu_Au.npz' with keys: smoothedMeasuredHeight_m, vDeflection_N, height_m, measuredHeight_m, seriesTime_s...)

# %%
list(D3011_data.keys())
# Out:
# ['smoothedMeasuredHeight_m',
#  'vDeflection_N',
#  'height_m',
#  'measuredHeight_m',
#  'seriesTime_s',
#  'time_s']

# %%
force_data = D3011_data['vDeflection_N']

# %%
force_data.shape
# Out:
# (1024, 800)

# %%
fig,ax = plt.subplots(dpi=100)

for curve in force_data:
    ax.plot(curve,c='red',alpha=0.1)

ax.set_xlabel('X data points',fontsize=12)
ax.set_ylabel('Force (nN)',fontsize=12)

ax.tick_params(labelsize=10,direction='in')

ax.set_xlim([0,force_data.shape[1]-1])

#fig.savefig('../data/figures/pca_examples/D3011_curves.png',dpi=300,bbox_inches='tight')

plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## ➗ *Split train and test*

# %%
train_data = force_data[:200]
test_data = force_data[200:]

# %%
fig,ax = plt.subplots(dpi=100)

for curve in train_data:
    ax.plot(curve,c='red',alpha=0.1)

ax.set_xlabel('X data points',fontsize=12)
ax.set_ylabel('Force (nN)',fontsize=12)

ax.tick_params(labelsize=10,direction='in')

ax.set_title("Train data")

ax.set_xlim([0,train_data.shape[1]-1])

plt.show()

# %%
fig,ax = plt.subplots(dpi=100)

for curve in test_data:
    ax.plot(curve,c='red',alpha=0.1)

ax.set_xlabel('X data points',fontsize=12)
ax.set_ylabel('Force (nN)',fontsize=12)

ax.tick_params(labelsize=10,direction='in')

ax.set_title("Test data")

ax.set_xlim([0,test_data.shape[1]-1])

plt.show()

# %%
train_data = [serie[:350] for serie in train_data]

# %%
fig,ax = plt.subplots(dpi=100)

for curve in train_data:
    ax.plot(curve,c='red',alpha=0.1)

ax.set_xlabel('X data points',fontsize=12)
ax.set_ylabel('Force (nN)',fontsize=12)

ax.tick_params(labelsize=10,direction='in')

ax.set_title("Train data [0:400]")

ax.set_xlim([0,350])

plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## 🧬 *Motif discovery with matrix profile*

# %%
size = len(train_data[0]) # x data points
sample_size = len(train_data) # rows
print(size, sample_size)
# Out:
# 350 200

# %%
joined_data = train_data[0]
for i in range(1, len(train_data)):
    joined_data = np.concatenate((joined_data, train_data[i]))
len(joined_data)
# Out:
# 70000

# %%
plt.figure(figsize=(6,3))
plt.plot(np.arange(8000), joined_data[:8000])
plt.ylabel("Sequence values")
plt.xlabel("Time")
plt.show()

# %%
# %%time
mp = matrixProfile.stomp(joined_data, size)
# Out:
# CPU times: user 37 s, sys: 42.3 ms, total: 37.1 s
# Wall time: 37 s

# %%
mp
# Out:
# (array([4.01215661, 3.91068618, 3.80016961, ..., 1.29724572, 1.29590651,
#         1.29478752]),
#  array([62294., 62295., 63346., ..., 25198., 25199., 25200.]))

# %%
len(mp)
# Out:
# 2

# %% [markdown]
#  Matrix Profile:

# %%
mp[0]
# Out:
# array([4.01215661, 3.91068618, 3.80016961, ..., 1.29724572, 1.29590651,
#        1.29478752])

# %%
len(mp[0])
# Out:
# 69651

# %% [markdown]
# Index of Matrix Profile:

# %%
mp[1]
# Out:
# array([62294., 62295., 63346., ..., 25198., 25199., 25200.])

# %%
len(mp[1])
# Out:
# 69651

# %%
plt.figure(figsize=(15,2))
plt.plot(np.arange(8000), mp[0][:8000], color='red')
plt.ylabel("Matrix Profile")
plt.show()

# %%
# %%time
mtfs, motif_d  = motifs.motifs(joined_data, mp, max_motifs=1000) # Computes the top k motifs from a matrix profile
# Out:
# CPU times: user 308 ms, sys: 3.8 ms, total: 312 ms
# Wall time: 311 ms

# %% [markdown]
# mtfs = motifs (list of lists of indexes representing the motif starting locations)

# %%
print(mtfs) # Return the index of the main motif and its main neighbors
print()
print(len(mtfs))
# Out:
# [[3602, 10602, 45252, 47002, 62052, 63102, 64502, 66252, 67302, 68352], [1497, 11297, 12697, 18997, 37547], [13329, 23829, 69329], [45024, 68124], [37191, 64141], [18351, 27450, 34100, 40052, 46352, 48102], [13147, 23647, 35197, 69147], [865, 22215, 36915, 39015, 49865, 63515], [7068, 9168, 10917, 62366, 65166, 67613], [3842, 38139, 66493, 68593], [4468, 4812, 12165, 12515, 14614, 21615, 46111, 62565, 68866], [6410, 8860, 37910, 64859], [28096, 31947, 33347, 48747], [2422, 43028, 45470, 47228, 63324], [14340, 18537, 27636, 28685, 34286, 40238, 46538, 48288, 60183], [434, 29135, 30183, 32985, 35783, 43835, 58185], [64317, 66067], [7830, 11680, 20780, 21830, 25330, 41780, 44230, 51930, 56130, 59280], [2955, 24305], [4200, 12949, 17500, 32198, 45848, 48998], [25095, 25795, 27895, 31045, 46793, 67796, 69545], [10421, 67119], [5977, 35377, 57422], [15325, 17773, 18123, 19526, 29676], [26325, 55375, 56775], [15890, 52990], [9682, 19826, 33830, 34877, 47829, 54833], [17239, 21439, 41039], [31764, 33167, 37367, 44012], [1676, 11473, 19174, 28273, 33524, 37730, 64679], [45646, 59986], [15134, 51531], [5641, 21045, 42392, 52189], [22405, 29409, 56355, 59504, 63711], [2598, 30596], [658, 20256, 20604, 23053, 23402, 26551, 30407, 39853, 54204], [9858, 22808, 31556, 55009, 65509], [20016, 25971, 31221], [5069, 5423, 42174], [38571, 55725, 57824], [1320, 7617, 34572, 53825], [3406, 8660, 11107, 30007, 32809, 62911], [3205, 8103, 11952, 16858, 39260], [8459, 25606, 44509, 52555, 61305], [47404, 54399], [6159, 22595, 57246], [200, 36602, 43600, 49553, 57598, 60400], [13517, 13866, 40460, 50267, 52367, 61118], [16514, 24914], [2192, 36141, 66941], [16132, 30824, 44821], [2779, 22025], [14806, 27056], [15567, 18718, 28870], [32374, 50574], [38839, 54589], [9346, 66743], [42644, 56989, 58388], [41998, 50750, 53205], [24500, 50041], [53409, 58664], [35601, 58009, 61858], [2010, 17062, 21262, 39451, 40862, 52759, 59750], [8283, 63942], [15, 6660, 7341, 36397, 61602], [26147, 48553, 55194], [19350, 28454], [10245, 53640, 65891], [26727, 51226, 58926], [39677, 54028], [1128, 32630], [10056, 35959, 49251, 51006, 51712, 55908, 65706], [27261, 41263, 59104], [16337, 24738], [38315, 41463], [24108, 43358], [47624, 60942], [14102, 42820, 60652]]
#
# 78

# %% [markdown]
# motif_d = distances (list of minimum distances for each motif)

# %%
print(motif_d)
print()
print(len(motif_d))
# Out:
# [0.5963741354528347, 0.7030301314166405, 0.7551955592324884, 0.8199809492548361, 0.8306320708353342, 0.8661156104807468, 0.8763340133537276, 0.911723113411326, 0.9990232002177291, 1.0405398265722594, 1.0416339496414784, 1.058678895590473, 1.1073399290746275, 1.1088759060043032, 1.112084101837298, 1.1140307803358438, 1.1486098755583403, 1.1527465926173255, 1.1695369265043023, 1.1816561633087177, 1.2580595307646296, 1.3536154235563131, 1.3620018475236844, 1.377757101334466, 1.4143909020269174, 1.438698605232338, 1.4540374027879968, 1.4540683833335328, 1.4649625932326291, 1.4664207317236322, 1.511471006256301, 1.6104124456071427, 1.683152600541999, 1.7077194497685424, 1.7332081713330618, 1.757976501251915, 1.79778957769152, 1.8362997239060215, 1.8944454922381404, 1.9108271585199987, 1.9148586588758, 1.9360945615538192, 1.996007211082581, 2.0332363054015814, 2.0391344762158967, 2.045045872390558, 2.138841370300512, 2.148372601674126, 2.1643765567132953, 2.207157117282003, 2.2159580505024365, 2.2310540507250205, 2.236354130213341, 2.2533417398630156, 2.281173793121544, 2.3383779811453826, 2.3469818899092565, 2.3910390486090773, 2.394937536435842, 2.483641309466432, 2.523533313145946, 2.5674618189460605, 2.602290363839618, 2.6106434084083134, 2.6120274208117387, 2.6901535449815914, 2.7061668895192152, 2.8375240094768026, 2.8452377101780946, 2.886983798022178, 3.0775481205754516, 3.0894333126080475, 3.172782154595544, 3.344078158776811, 3.8689327693699798, 4.282243298774939, 5.106724071287707, 6.077103375601836]
#
# 78

# %%
motif_center_list = []
for motif in mtfs:
    center_pointers = list(np.arange(motif[0], motif[0]+size)) # Indexes of the central subsequence 
    # each center point start at the starting point of the significant motif (a time serie) and finish at the end of the serie
    motif_center_ts = joined_data[center_pointers] # use the indexes to extract the correspondent sequence in joined_data
    motif_center_list.append(motif_center_ts)

# %%
center_pointers
# Out:
# [14102,
#  14103,
#  14104,
#  14105,
#  14106,
#  14107,
#  14108,
#  14109,
#  14110,
#  14111,
#  14112,
#  14113,
#  14114,
#  14115,
#  14116,
#  14117,
#  14118,
#  14119,
#  14120,
#  14121,
#  14122,
#  14123,
#  14124,
#  14125,
#  14126,
#  14127,
#  14128,
#  14129,
#  14130,
#  14131,
#  14132,
#  14133,
#  14134,
#  14135,
#  14136,
#  14137,
#  14138,
#  14139,
#  14140,
#  14141,
#  14142,
#  14143,
#  14144,
#  14145,
#  14146,
#  14147,
#  14148,
#  14149,
#  14150,
#  14151,
#  14152,
#  14153,
#  14154,
#  14155,
#  14156,
#  14157,
#  14158,
#  14159,
#  14160,
#  14161,
#  14162,
#  14163,
#  14164,
#  14165,
#  14166,
#  14167,
#  14168,
#  14169,
#  14170,
#  14171,
#  14172,
#  14173,
#  14174,
#  14175,
#  14176,
#  14177,
#  14178,
#  14179,
#  14180,
#  14181,
#  14182,
#  14183,
#  14184,
#  14185,
#  14186,
#  14187,
#  14188,
#  14189,
#  14190,
#  14191,
#  14192,
#  14193,
#  14194,
#  14195,
#  14196,
#  14197,
#  14198,
#  14199,
#  14200,
#  14201,
#  14202,
#  14203,
#  14204,
#  14205,
#  14206,
#  14207,
#  14208,
#  14209,
#  14210,
#  14211,
#  14212,
#  14213,
#  14214,
#  14215,
#  14216,
#  14217,
#  14218,
#  14219,
#  14220,
#  14221,
#  14222,
#  14223,
#  14224,
#  14225,
#  14226,
#  14227,
#  14228,
#  14229,
#  14230,
#  14231,
#  14232,
#  14233,
#  14234,
#  14235,
#  14236,
#  14237,
#  14238,
#  14239,
#  14240,
#  14241,
#  14242,
#  14243,
#  14244,
#  14245,
#  14246,
#  14247,
#  14248,
#  14249,
#  14250,
#  14251,
#  14252,
#  14253,
#  14254,
#  14255,
#  14256,
#  14257,
#  14258,
#  14259,
#  14260,
#  14261,
#  14262,
#  14263,
#  14264,
#  14265,
#  14266,
#  14267,
#  14268,
#  14269,
#  14270,
#  14271,
#  14272,
#  14273,
#  14274,
#  14275,
#  14276,
#  14277,
#  14278,
#  14279,
#  14280,
#  14281,
#  14282,
#  14283,
#  14284,
#  14285,
#  14286,
#  14287,
#  14288,
#  14289,
#  14290,
#  14291,
#  14292,
#  14293,
#  14294,
#  14295,
#  14296,
#  14297,
#  14298,
#  14299,
#  14300,
#  14301,
#  14302,
#  14303,
#  14304,
#  14305,
#  14306,
#  14307,
#  14308,
#  14309,
#  14310,
#  14311,
#  14312,
#  14313,
#  14314,
#  14315,
#  14316,
#  14317,
#  14318,
#  14319,
#  14320,
#  14321,
#  14322,
#  14323,
#  14324,
#  14325,
#  14326,
#  14327,
#  14328,
#  14329,
#  14330,
#  14331,
#  14332,
#  14333,
#  14334,
#  14335,
#  14336,
#  14337,
#  14338,
#  14339,
#  14340,
#  14341,
#  14342,
#  14343,
#  14344,
#  14345,
#  14346,
#  14347,
#  14348,
#  14349,
#  14350,
#  14351,
#  14352,
#  14353,
#  14354,
#  14355,
#  14356,
#  14357,
#  14358,
#  14359,
#  14360,
#  14361,
#  14362,
#  14363,
#  14364,
#  14365,
#  14366,
#  14367,
#  14368,
#  14369,
#  14370,
#  14371,
#  14372,
#  14373,
#  14374,
#  14375,
#  14376,
#  14377,
#  14378,
#  14379,
#  14380,
#  14381,
#  14382,
#  14383,
#  14384,
#  14385,
#  14386,
#  14387,
#  14388,
#  14389,
#  14390,
#  14391,
#  14392,
#  14393,
#  14394,
#  14395,
#  14396,
#  14397,
#  14398,
#  14399,
#  14400,
#  14401,
#  14402,
#  14403,
#  14404,
#  14405,
#  14406,
#  14407,
#  14408,
#  14409,
#  14410,
#  14411,
#  14412,
#  14413,
#  14414,
#  14415,
#  14416,
#  14417,
#  14418,
#  14419,
#  14420,
#  14421,
#  14422,
#  14423,
#  14424,
#  14425,
#  14426,
#  14427,
#  14428,
#  14429,
#  14430,
#  14431,
#  14432,
#  14433,
#  14434,
#  14435,
#  14436,
#  14437,
#  14438,
#  14439,
#  14440,
#  14441,
#  14442,
#  14443,
#  14444,
#  14445,
#  14446,
#  14447,
#  14448,
#  14449,
#  14450,
#  14451]

# %%
len(motif_center_list) # 38 motifs!
# Out:
# 78

# %% [markdown]
# ***

# %% [markdown]
# ## 🗺️ *SOM Training*

# %% [markdown]
# ##### How the structure type affect the results?
#
# *Possibilities* ([Matrix Profile Github](https://github.com/target/matrixprofile-ts)):
# 1. grid_four ("Standard"): Grid type of connections when each oscillator has connections with left, upper, right, lower neighbors.
# 2. honeycomb: Grid type of connections when each oscillator has connections with left, upper-left, upper-right, right, right-lower, lower-left neighbors.
# 3. func_neighbor: Grid type of connections when existance of each connection is defined by the SOM rule on each step of simulation.
# 4. grid_eight: Grid type of connections when each oscillator has connections with left, upper-left, upper, upper-right, right, right-lower, lower, lower-left neighbors.

# %%
# %time
rows = 3
cols = 3
structure = type_conn.grid_four # enumeration of connection types for SOM (inheritance of pyclustering)
network = dtwsom.DtwSom(rows, cols, structure)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 2.86 µs

# %%
# %%time
network.train(motif_center_list, 50)
# Out:
# Epoch 1 achieved an average quantization error of 4.3221
# Epoch 2 achieved an average quantization error of 4.7797
# Epoch 3 achieved an average quantization error of 4.9472
# Epoch 4 achieved an average quantization error of 5.2119
# Epoch 5 achieved an average quantization error of 5.4247
# Epoch 6 achieved an average quantization error of 5.5677
# Epoch 7 achieved an average quantization error of 5.6727
# Epoch 8 achieved an average quantization error of 5.6279
# Epoch 9 achieved an average quantization error of 5.578
# Epoch 10 achieved an average quantization error of 5.5814
# Epoch 11 achieved an average quantization error of 5.5201
# Epoch 12 achieved an average quantization error of 5.5143
# Epoch 13 achieved an average quantization error of 5.4122
# Epoch 14 achieved an average quantization error of 5.4752
# Epoch 15 achieved an average quantization error of 5.4674
# Epoch 16 achieved an average quantization error of 5.3941
# Epoch 17 achieved an average quantization error of 5.5376
# Epoch 18 achieved an average quantization error of 5.4717
# Epoch 19 achieved an average quantization error of 5.4372
# Epoch 20 achieved an average quantization error of 5.6341
# Epoch 21 achieved an average quantization error of 5.7213
# Epoch 22 achieved an average quantization error of 5.7783
# Epoch 23 achieved an average quantization error of 5.8595
# Epoch 24 achieved an average quantization error of 5.8082
# Epoch 25 achieved an average quantization error of 5.7809
# Epoch 26 achieved an average quantization error of 5.7842
# Epoch 27 achieved an average quantization error of 5.8076
# Epoch 28 achieved an average quantization error of 5.7191
# Epoch 29 achieved an average quantization error of 5.6489
# Epoch 30 achieved an average quantization error of 5.6392
# Epoch 31 achieved an average quantization error of 5.6604
# Epoch 32 achieved an average quantization error of 5.7013
# Epoch 33 achieved an average quantization error of 5.7647
# Epoch 34 achieved an average quantization error of 5.8496
# Epoch 35 achieved an average quantization error of 5.6327
# Epoch 36 achieved an average quantization error of 5.4957
# Epoch 37 achieved an average quantization error of 5.4392
# Epoch 38 achieved an average quantization error of 5.4065
# Epoch 39 achieved an average quantization error of 5.3553
# Epoch 40 achieved an average quantization error of 5.3671
# Epoch 41 achieved an average quantization error of 5.3925
# Epoch 42 achieved an average quantization error of 5.3972
# Epoch 43 achieved an average quantization error of 5.3936
# Epoch 44 achieved an average quantization error of 5.3958
# Epoch 45 achieved an average quantization error of 5.3956
# Epoch 46 achieved an average quantization error of 5.3901
# Epoch 47 achieved an average quantization error of 5.3772
# Epoch 48 achieved an average quantization error of 5.3608
# Epoch 49 achieved an average quantization error of 5.3507
# Epoch 50 achieved an average quantization error of 5.3461
# CPU times: user 2h 30min 26s, sys: 108 ms, total: 2h 30min 26s
# Wall time: 2h 30min 27s
# 50

# %% [markdown]
# ***

# %% [markdown]
# ## *Analysis of the results*

# %%
network.show_distance_matrix()

# %%
network.show_winner_matrix()

# %%
n_neurons = network._size
fig, axs = plt.subplots(3,3,figsize=(8, 6), sharex=True, sharey=True)
for neuron_index in range(n_neurons):
    col = math.floor(neuron_index/3) # round numbers down to the nearest integer:
    #math.ceil: round a number UP to the nearest integer
    row = neuron_index % 3
    neuron_weights = network._weights[neuron_index]
    axs[row, col].plot(np.arange(len(neuron_weights)), neuron_weights, label=str(neuron_index))
    axs[row, col].set_title("Unit: "+str(neuron_index))
    if col == 0:
        axs[row, col].set_ylabel("Sequence values")
    if row == 2:
        axs[row, col].set_xlabel("Time")
plt.tight_layout()
plt.show()

# %%
n = rows
n_neurons = network._size
fig, axs = plt.subplots(n,n,figsize=(10, 6), sharex=True, sharey=True)
for neuron_index in range(n_neurons):
    col = math.floor(neuron_index/n)
    row = neuron_index % n
    cluster_list = network.capture_objects[neuron_index]
    for member_index in cluster_list:
        axs[row, col].plot(np.arange(len(motif_center_list[member_index])), motif_center_list[member_index])
    axs[row, col].set_title("Cluster: "+str(neuron_index))
    if col == 0:
        axs[row, col].set_ylabel("Seq. values")
    if row == 2:
        axs[row, col].set_xlabel("Time")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cluster 3

# %%
fig, axs = plt.subplots(2,10 ,figsize=(15, 4), sharex=True, sharey=True)
cluster_list = network.capture_objects[3]
for i, member_index in enumerate(cluster_list):
    col = math.floor(i/2)
    row = i % 2
    axs[row, col].plot(np.arange(len(motif_center_list[member_index])), motif_center_list[member_index])
plt.show()

# %% [markdown]
# ### Cluster 5

# %%
fig, axs = plt.subplots(2,6 ,figsize=(15, 4), sharex=True, sharey=True)
cluster_list = network.capture_objects[5]
for i, member_index in enumerate(cluster_list):
    col = math.floor(i/2)
    row = i % 2
    axs[row, col].plot(np.arange(len(motif_center_list[member_index])), motif_center_list[member_index])
plt.show()

# %% [markdown]
# ### Cluster 7

# %%
fig, axs = plt.subplots(2,11 ,figsize=(15, 4), sharex=True, sharey=True)
cluster_list = network.capture_objects[7]
for i, member_index in enumerate(cluster_list):
    col = math.floor(i/2)
    row = i % 2
    axs[row, col].plot(np.arange(len(motif_center_list[member_index])), motif_center_list[member_index])
plt.show()

# %% [markdown]
# ### Cluster 8

# %%
fig, axs = plt.subplots(2,10 ,figsize=(15, 4), sharex=True, sharey=True)
cluster_list = network.capture_objects[8]
for i, member_index in enumerate(cluster_list):
    col = math.floor(i/2)
    row = i % 2
    axs[row, col].plot(np.arange(len(motif_center_list[member_index])), motif_center_list[member_index])
plt.show()

# %%
help(network)
# Out:
# Help on DtwSom in module dtwsom object:
#
# class DtwSom(pyclustering.nnet.som.som)
#  |  DtwSom(rows, cols, conn_type=<type_conn.grid_eight: 1>, parameters=None, dtw_params=None)
#  |
#  |  !
#  |  @brief Represents self-organized feature map (SOM) with the Dynamic Time Warping (DTW) distance.
#  |  @details The self-organizing feature map (SOM) method is a powerful tool for the visualization of
#  |           of high-dimensional data. It converts complex, nonlinear statistical relationships between
#  |           high-dimensional data into simple geometric relationships on a low-dimensional display.
#  |           The DTW-SOM is then an adaptation of SOM for time-series subsequences with variable lengths
#  |           which used the Dynamic Time Warping (DTW) distance as the similarity metric.
#  |
#  |  Method resolution order:
#  |      DtwSom
#  |      pyclustering.nnet.som.som
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, rows, cols, conn_type=<type_conn.grid_eight: 1>, parameters=None, dtw_params=None)
#  |      !
#  |      @brief Constructor of DTW self-organized map.
#  |
#  |      @param[in] rows (uint): Number of neurons in the column (number of rows).
#  |      @param[in] cols (uint): Number of neurons in the row (number of columns).
#  |      @param[in] conn_type (type_conn): Type of connection between oscillators in the network (grid four, grid eight,
#  |      honeycomb, function neighbour).
#  |      @param[in] parameters (DtwSomParameters): Parameters for training the DTW SOM.
#  |      @param[in] dtw_params (DtwParameters): Parameters specific for the DTW distance function.
#  |
#  |  get_density_matrix(self, surface_divider=20.0)
#  |      !
#  |      @brief Calculates density matrix (P-Matrix).
#  |
#  |      @param[in] surface_divider (double): Divider in each dimension that affect radius for density measurement.
#  |
#  |      @return (list) Density matrix (P-Matrix).
#  |
#  |      @see get_distance_matrix()
#  |
#  |  get_distance_matrix(self)
#  |      !
#  |      @brief Calculates distance matrix (U-matrix).
#  |      @details The U-Matrix visualizes based on the distance in input space between a weight vector and its neighbors
#  |      on map.
#  |
#  |      @return (list) Distance matrix (U-matrix).
#  |
#  |      @see show_distance_matrix()
#  |      @see get_density_matrix()
#  |
#  |  save_distance_matrix(self, output_file)
#  |
#  |  save_winner_matrix(self, output_file)
#  |
#  |  show_distance_matrix(self)
#  |      !
#  |      @brief Shows gray visualization of U-matrix (distance matrix).
#  |
#  |      @see get_distance_matrix()
#  |
#  |  train(self, data, epochs, autostop=False, anchors=None)
#  |      !
#  |      @brief Trains DTW self-organized feature map (DTW-SOM).
#  |
#  |      @param[in] data (list): Input data - list of points where each point is represented by list of features, for
#  |      example coordinates.
#  |      @param[in] epochs (uint): Number of epochs for training.
#  |      @param[in] autostop (bool): Automatic termination of learning process when adaptation is not occurred.
#  |      @param[in] anchors (list): List of input patterns that should be considered as anchors. Only used for the
#  |      anchor initialization.
#  |
#  |      @return (uint) Number of learning iterations.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from pyclustering.nnet.som.som:
#  |
#  |  __del__(self)
#  |      !
#  |      @brief Destructor of the self-organized feature map.
#  |
#  |  __getstate__(self)
#  |      @brief Returns state of SOM network that can be used to store network.
#  |
#  |  __len__(self)
#  |      !
#  |      @brief Returns size of the network that defines by amount of neuron in it.
#  |
#  |      @return (uint) Size of self-organized map (amount of neurons).
#  |
#  |  __setstate__(self, som_state)
#  |      @brief Set state of SOM network that can be used to load network.
#  |
#  |  get_winner_number(self)
#  |      !
#  |      @brief Calculates number of winner at the last step of learning process.
#  |
#  |      @return (uint) Number of winner.
#  |
#  |  show_density_matrix(self, surface_divider=20.0)
#  |      !
#  |      @brief Show density matrix (P-matrix) using kernel density estimation.
#  |
#  |      @param[in] surface_divider (double): Divider in each dimension that affect radius for density measurement.
#  |
#  |      @see show_distance_matrix()
#  |
#  |  show_network(self, awards=False, belongs=False, coupling=True, dataset=True, marker_type='o')
#  |      !
#  |      @brief Shows neurons in the dimension of data.
#  |
#  |      @param[in] awards (bool): If True - displays how many objects won each neuron.
#  |      @param[in] belongs (bool): If True - marks each won object by according index of neuron-winner (only when
#  |                  dataset is displayed too).
#  |      @param[in] coupling (bool): If True - displays connections between neurons (except case when function neighbor
#  |                  is used).
#  |      @param[in] dataset (bool): If True - displays inputs data set.
#  |      @param[in] marker_type (string): Defines marker that is used to denote neurons on the plot.
#  |
#  |  show_winner_matrix(self)
#  |      !
#  |      @brief Show a winner matrix where each element corresponds to neuron and value represents
#  |             amount of won objects from input data-space at the last training iteration.
#  |
#  |      @see show_distance_matrix()
#  |
#  |  simulate(self, input_pattern)
#  |      !
#  |      @brief Processes input pattern (no learining) and returns index of neuron-winner.
#  |             Using index of neuron winner catched object can be obtained using property capture_objects.
#  |
#  |      @param[in] input_pattern (list): Input pattern.
#  |
#  |      @return (uint) Returns index of neuron-winner.
#  |
#  |      @see capture_objects
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from pyclustering.nnet.som.som:
#  |
#  |  awards
#  |      !
#  |      @brief Return amount of captured objects by each neuron after training.
#  |
#  |      @return (list) Amount of captured objects by each neuron.
#  |
#  |      @see train()
#  |
#  |  capture_objects
#  |      !
#  |      @brief Returns indexes of captured objects by each neuron.
#  |      @details For example, a network with size 2x2 has been trained on a sample with five objects. Suppose neuron #1
#  |                won an object with index `1`, neuron #2 won objects `0`, `3`, `4`, neuron #3 did not won anything and
#  |                finally neuron #4 won an object with index `2`. Thus, for this example we will have the following
#  |                output `[[1], [0, 3, 4], [], [2]]`.
#  |
#  |      @return (list) Indexes of captured objects by each neuron.
#  |
#  |  size
#  |      !
#  |      @brief Return size of self-organized map that is defined by total number of neurons.
#  |
#  |      @return (uint) Size of self-organized map (number of neurons).
#  |
#  |  weights
#  |      !
#  |      @brief Return weight of each neuron.
#  |
#  |      @return (list) Weights of each neuron.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from pyclustering.nnet.som.som:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
network.capture_objects
# Out:
# [[17, 39],
#  [7, 52],
#  [34, 54],
#  [0, 1, 4, 8, 11, 12, 15, 18, 24, 25, 27, 31, 36, 37, 43, 48, 49, 67, 70, 77],
#  [],
#  [33, 51, 57, 58, 59, 62, 63, 65, 68, 72, 75],
#  [],
#  [2,
#   3,
#   6,
#   9,
#   10,
#   13,
#   14,
#   16,
#   19,
#   20,
#   21,
#   22,
#   23,
#   28,
#   29,
#   30,
#   32,
#   42,
#   45,
#   50,
#   64,
#   76],
#  [5, 26, 35, 38, 40, 41, 44, 46, 47, 53, 55, 56, 60, 61, 66, 69, 71, 73, 74]]

# %%
plt.plot(range(len(motif_center_list[0])), motif_center_list[0])
